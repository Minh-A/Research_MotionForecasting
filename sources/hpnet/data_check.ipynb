# %%
import torch

data = torch.load("/home/cv9/smin/next/HPNet/data/test/processed_data/1.pt")

# %%
data.keys()
# Out:
# dict_keys(['city', 'scenario_id', 'agent', 'lane', 'centerline', ('centerline', 'lane'), ('lane', 'lane')])
